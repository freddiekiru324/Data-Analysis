# %% [markdown]
# ## PYTHON FINAL CODE CHALLENGE APRIL CLASS
# ## NAME:
# * INSTRUCTIONS:
#     - Make sure to input your name in this markdown
#     - When saving your work,maek sure ot writr your name on the saved file i.e Python Final code challenge-Tarus.ipynb
#     - Make sure to run all your cells before submitting your work.(i.e click run all button up there)
#     - Do not submit your work with errors
#     - DO NOT USE AI or somebodys work

# %% [markdown]
# **A simple system to manage students and display their results.**
# - Background
#     - A school wants a basic system to store student information, calculate their average mark, assign a grade, and display a report.**
#     - There are regular students and prefect students — prefects get a special title on their report.**

# %% [markdown]
# ## Part 1 — Variables & Data Types
# - Store the following for a student:
#     - name = "Aisha"
#     - age = 16
#     - student_id = "STU001"
#     - marks = [78, 65, 90, 55, 82]
#     - is_enrolled = True
# - Print each one with a label e.g. Name: Aisha
# - Calculate the average mark from the list.
#     - Print it rounded to 1 decimal place e.g. Average Mark: 74.0

# %%
#variables
name="aisha"
age=16
student_id="STU001"
marks=[78,65,90,55,82]
total=float(78+65+90+55+82)/5
is_enrolled=True
#calculate

#if statement
    
#print
print("="*40)
print(f"Name:{name}")
print(f"Age:{age}")
print(f"Student_Id:{student_id}")
print(f"Marks:{marks}")
print(f"average_mark:{total}")
print("="*40)
# Out:
# ...
# Name:aisha
# Age:16
# Student_Id:STU001
# Marks:[78, 65, 90, 55, 82]
# average_mark:74.0
# ...

# %% [markdown]
# ## Part 2 — if / elif / else
# - Print the grade based on the average:
#     - 70 and above  →  A
#     - 60 – 69       →  B
#     - 50 – 59       →  C
#     - Below 50      →  Fail

# %%
if total>=70:
    print("you scored an A")
elif 60-69:
    print("B")   
elif 50-59:
    print("C") 
else:
    print("Fail")
# Out:
# you scored an A

# %% [markdown]
# ## Part 3 — Loops
# - Given this list:
#        - pythonstudents = ["Aisha", "Brian", "Cynthia", "David"]
#
# - Use a for loop to print each student with a number e.g. 1. Aisha
# - Use a while loop to print a 3-second countdown before results are announced e.g. 3... 2... 1... Results!

# %%
pythonstudents=["1.Aisha","2.Brian","3.Cynthia","4.David"]
for x in pythonstudents:
    print(x)
    #print
print("\nCountdown:")
y = 3
#while
while y > 0:
    print(f"{y}...")
    y -= 1
#print
print("Results!")
# Out:
# 1.Aisha
# 2.Brian
# 3.Cynthia
# 4.David
#
# Countdown:
# 3...
# 2...
# 1...
# Results!

# %% [markdown]
# ## Part 4 — OOP
# ### Create a class Student with:
#
# - Attributes: name, age, marks (a list)
# - Method average() — calculates and returns the average
# - Method grade() — returns the letter grade (A / B / C / Fail)
# - Method report() — prints a full student report
#
# ### Create a class Prefect that inherits from Student:
#
# - Extra attribute: role (e.g. "Head Prefect")
# - Overrides report() to also print the role
# - average() and grade() work as inherited — no changes needed
#
# ### Create one Student and one Prefect, call report() on both.

# %%
class student:
    def __init__ (self,name,age,marks):
        self.name=name
        self.age=age
        self.marks=list(marks)
    def average(self):
        #calculate
        total=float(78+65+90+55+82)/5
        return(f"average:{total}")
    def grade(self):
        if total >= 70:
            print("A")
        elif 60-69:
            print("B")
        elif 50-59:
            print("C")
        else:
            print("Fail")
    def report(self):
        print("       Student Report          ")
        print(f"Name  :{self.name}")
        print(f"Age   :{self.age}")
        print(f"Marks  :{total}")
class prefect(student):
    def __init__ (self,name,age,marks,role): 
        self.name=name
        self.age=age
        self.marks=marks
        self.role=role
    def report(self):
        print("-"*40)
        print("            Prefect Report      ")
        print(f"Name: {self.name}")
        print(f"age:  {self.age}")
        print(f"marks:{total}")
        print(f"Role :{self.role}")
        print("="*40)
              
student1=student("Aisha",20,[78,65,90,55,82])
prefect1=prefect("Brian",18,[78,65,90,55,82],"Head Prefect")
student1.report()

prefect1.report()
# Out:
# ......Student Report......
# Name  :Aisha
# Age   :20
# Marks  :74.0
# ----------------------------------------
# .........Prefect Report........
# Name: Brian
# age:  18
# marks:74.0
# Role :Head Prefect
# ...
